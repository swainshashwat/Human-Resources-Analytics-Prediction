# %% [markdown]
# # PROBLEM STATEMENT
# This is the POC for Human Resource Attrition in an organisation.
#
# Attrition, in Human Resource terminology, refers to the phenomenon of the employees leaving the company.
#
# I have selected multiple features like satisfaction level of the employee, his/her last evaluation score, the number of projects completed by the individual, average monthly hours he/she has spent in the workspace, number of years spent in the orgaisation, if he/she has been involved in a work-place accident, if he/she has had a promotion in the last 5 years in the company, the department they work in and the category of salary they receive.
#
# We shall use these features to predict the attrition of the organisation (left).
#
# Applied multiple algorithms to train and evaluate the problem statement are Logistic Regression, K-Nearest Neighbors Classifier, Support Vector Machine Classifier, Decision Tree Classifier, Random Forest Classifier, AdaBoost Classifier, Gaussian Naive Bayes classifier, Quadratic Discriminant Analysis and Linear Discriminant Analysis.

# %% [markdown]
# # METHODOLOGY

# %% [markdown]
# ## Importing the necessary packages

# %% [markdown]
# ### Pandas
# **[Pandas](https://pandas.pydata.org/pandas-docs/version/0.20/)** is a Python package providing fast, flexible, and expressive data structures designed to make working with structured (tabular, multidimensional, potentially heterogeneous) and time series data both easy and intuitive.
#
# ### Numpy
# **[Numpy](https://docs.scipy.org/doc/numpy/user/quickstart.html)** is the fundamental package for scientific computing with Python. It contains among other things:
#
# * powerful N-dimensional array object
# * sophisticated (broadcasting) functions
# * tools for integrating C/C++ and Fortran code
# * useful linear algebra, Fourier transform, and random number capabilities
#
# ### Matplotlib
# **[Matplotlib](https://matplotlib.org/contents.html)** is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shells, the Jupyter notebook, web application servers, and four graphical user interface toolkits.
#
# ### Seaborn
# **[Seaborn](https://seaborn.pydata.org/tutorial.html)** is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics.

# %%
# importing the basic packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **[Magic Commands](http://ipython.readthedocs.io/en/stable/interactive/tutorial.html#magics-explained)**

# %%
# Special line in jupyter notebooks that helps to display the plot in the notebook itself

# %matplotlib inline

# %% [markdown]
# ## Data Preprocessing

# %%
# importing the datafile
df = pd.read_csv('turnover.csv')

# %% [markdown]
# ### Understanding the data

# %% [markdown]
# >DataFrame.info(verbose=None, buf=None, max_cols=None, memory_usage=None, null_counts=None)
#
# Print a concise summary of a DataFrame.

# %%
# Checking for NULL values
# From the results, it's clear that the dataset does NOT contain any null/nan/empty values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# >DataFrame.describe(percentiles=None, include=None, exclude=None)
#
# Generates descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.

# %%
# Checking the distribution of the numerical attributes
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
# Checking the names of the columns
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
# Checking the values in the output label
df.left.unique()
# Out:
# array([1, 0])

# %%
left_count = df_new.left.groupby(by=df_new.left).count()
print(left_count)
print("---------------------------------")
print(df_new.left.count())
# Out:
# left
# 0    11428
# 1     3571
# Name: left, dtype: int64
# ---------------------------------
# 14999

# %% [markdown]
# ### Encoding 'sales' and 'salary'
#
# As the columns **sales** and **salary** are non-numerical column (Object type), we convert them into numerical attributes.

# %% [markdown]
# #### sales

# %%
# Checking the unique values in the 'salary' column
df.sales.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
# counting the number unique values in the 'sales' column
sales_grouped = pd.DataFrame(df.sales.groupby(by=df.sales).count())

print(df.sales.groupby(by=df.sales).count())
print("---------------------------------")
print("Total = "+ str(df.sales.count()))
# Out:
# sales
# IT             1227
# RandD           787
# accounting      767
# hr              739
# management      630
# marketing       858
# product_mng     902
# sales          4140
# support        2229
# technical      2720
# Name: sales, dtype: int64
# ---------------------------------
# Total = 14999

# %%
# plotting the grouped unique values in the 'sales' column
sales_grouped.plot(kind='bar', figsize=(15,6))

# %% [markdown]
# #### Label Encoding/ Integer Encoding
# An approach to encoding categorical values is to use a technique called label encoding
# Label encoding is simply converting each value in a column to a number.
#
# [Scikit-learn's LabelEncoder Documentation](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# initializing
label_encoder = LabelEncoder()

# %%
sales_label = label_encoder.fit_transform(df.sales) # converting all 'categorical values' to 'numerical'

print(type(sales_label[0])) # checking the data type for the values in 'sales_label'

sales_label
# Out:
# <class 'numpy.int64'>
# array([7, 7, 7, ..., 8, 8, 8])

# %% [markdown]
# #### salary

# %%
# Checking the unique values of the 'salary' attribute
df.salary.unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
# count salary
salary_grouped = pd.DataFrame(df.salary.groupby(by=df.salary).count())

print(df.salary.groupby(by=df.salary).count())
print("---------------------------------")
print(df.salary.count())
# Out:
# salary
# high      1237
# low       7316
# medium    6446
# Name: salary, dtype: int64
# ---------------------------------
# 14999

# %%
# plotting the grouped unique values in the 'salary' column
salary_grouped.plot(kind='bar', figsize=(10,6))

# %% [markdown]
# #### Dummy Encoding
# Dummy coding refers to the process of coding a categorical variable into dichotomous variables.
#
# [Pandas Dummy Encoding Documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)

# %%
salary_label = pd.get_dummies(df.salary, prefix='sal')
salary_label.head()
# Out:
#    sal_high  sal_low  sal_medium
# 0         0        1           0
# 1         0        0           1
# 2         0        0           1
# 3         0        1           0
# 4         0        1           0

# %% [markdown]
# ### Concatenating new columns to the original DataFrame

# %%
# concatenating 'salary_label' column
df_new = pd.concat([df, salary_label], axis=1, join='inner')

# %%
# adding the 'sales_label' column
df_new['sales_encoded'] = sales_label
df_new.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary  sal_high  sal_low  sal_medium  sales_encoded
# ...

# %%
# Removing 'sales' and 'salary' columns (character fields removed and substituted for model purpose
df_new = df_new.drop(['sales','salary'], axis=1)

# %%
df_new.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sal_high  \
# 0                   3              0     1                      0         0
# 1                   6              0     1                      0         0
# 2                   4              0     1                      0         0
# 3                   5              0     1                      0         0
# 4                   3              0     1                      0         0
#
#    sal_low  sal_medium  sales_encoded
# ...

# %%
# As you can see, all columns are clearly numerical
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 12 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sal_high                 14999 non-null uint8
# sal_low                  14999 non-null uint8
# sal_medium               14999 non-null uint8
# sales_encoded            14999 non-null int64
# dtypes: float64(2), int64(7), uint8(3)
# memory usage: 1.1 MB

# %% [markdown]
# ### Separating FEATURES and LABELS

# %%
# X = features
X = df_new.drop('left',axis=1)
X.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years  sal_high  \
# 0                   3              0                      0         0
# 1                   6              0                      0         0
# 2                   4              0                      0         0
# 3                   5              0                      0         0
# 4                   3              0                      0         0
#
#    sal_low  sal_medium  sales_encoded
# 0        1           0              7
# ...

# %%
# Y = labels
Y = df_new['left']
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: left, dtype: int64

# %% [markdown]
# ## DATA VISUALIZATION

# %%
# Distribution of time spent in the company
pd.DataFrame(df_new.time_spend_company.groupby(by=df_new.time_spend_company).count()).plot(kind='bar', figsize=(13,6), title='Years spent in the Company', colormap='summer')

# %%
# plotting the grouped unique values in the 'sales' column
sales_grouped.plot(kind='bar', figsize=(15,6), title="Count plot for all Departments", colormap='prism')

# %%
# plotting the grouped unique values in the 'salary' column
salary_grouped.plot(kind='bar', figsize=(10,6), title='Frequency of all "salary" categories', colormap='Greens_r')

# %%
# plotting the 
pd.DataFrame(df_new.left.groupby(by=df_new.left).count()).plot(kind='bar', color='brown')

# %% [markdown]
# ## Graphical Inferences

# %% [markdown]
# * We can clearly see from the **violin plot** below that employees categorized by their respective departments who produce lower satisfaction levels have a higher tendency to leave the company.
# * The black line shows the average satisfaction level in the organization.

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.plot([-5, 250], [df.last_evaluation.mean(),df.satisfaction_level.mean()], 'k-', lw=2)
sns.violinplot(ax=ax, data=df,x='sales', y = 'satisfaction_level',pallete='muted',hue='left')

# %% [markdown]
# * We can clearly see from the **violin plot** below that employees who left the organization tend to have extreme evalution scores( i.e. extremely higher than average and extremely lower than average), whereas employees who stayed had score near the mean evaluation score.
# * The black line shows the mean of the evaluation scores.

# %%
fig, ax = plt.subplots(figsize=(17,8))
ax.plot([-5, 250], [df.last_evaluation.mean(),df.last_evaluation.mean()], 'k-', lw=2)
sns.violinplot(ax=ax, data=df,x='sales', y = 'last_evaluation',palette='hot_r',hue='left')

# %% [markdown]
# * We can clearly see from the **box plot** below that employees with 'low' salary have slightly lower satisfaction levels than employees with 'medium' or 'high' range salaries.

# %%
fig, ax = plt.subplots(figsize=(5,10))
sns.boxplot(ax=ax, data=df,x='salary', y = 'satisfaction_level',palette='deep')

# %% [markdown]
# * We can clearly see from the **box plot** below that employees who had spent more number of years in the Organization had a higher tendency of leaving the Organization.

# %%
# line showing mean of time_spend_company
fig, ax = plt.subplots(figsize=(5,7))
ax.plot([-5, 250],
        [df.time_spend_company.mean(),df.time_spend_company.mean()],
        'k-', lw=2) 
plt.title('Years spent in the company vs Left the company')
plt.ylabel('Years spent in the company')
sns.boxplot(ax=ax, data=df,y='time_spend_company', x = 'left',palette='cool')

# %% [markdown]
# ## DATA NORMALIZATION

# %% [markdown]
# ## Feature Scaling
# * Feature scaling is a method used to standardize the range of independent variables or features of data.
# * In data processing, it is also known as data normalization and is generally performed during the data preprocessing step.

# %% [markdown]
# ### Standard Scaler
# 1. Standardize features by removing the mean and scaling to unit variance
#
# 2. Centering and scaling happen independently on each feature by computing the relevant statistics on the samples in the training set.
#
# 3. Mean and standard deviation are then stored to be used on later data using the transform method.
#
# Standardization of a dataset is a common requirement for many machine learning estimators: they might behave badly if the individual feature do not more or less look like standard normally distributed data (e.g. Gaussian with 0 mean and unit variance).
#
# ## $$x' = \frac{x - \bar{x}}{\sigma}$$
#
# where ${\sigma}$ is standard deviation and $\bar{x}$ is mean.

# %%
# Scaling the data (for faster training)
from sklearn.preprocessing import StandardScaler

# %%
# initializing StandardScaler
scalar = StandardScaler()

# %%
# transforming the data
X_normalized = scalar.fit_transform(X)
X_normalized
# Out:
# array([[-0.93649469, -1.08727529, -1.46286291, ...,  1.02477511,
#         -0.8681323 ,  0.39372503],
#        [ 0.75281433,  0.84070693,  0.97111292, ..., -0.97582386,
#          1.15189816,  0.39372503],
#        [-2.02247906,  0.95755433,  2.59376348, ..., -0.97582386,
#          1.15189816,  0.39372503],
#        ...,
#        [-0.97671633, -1.08727529, -1.46286291, ...,  1.02477511,
#         -0.8681323 ,  0.74231612],
#        [-2.02247906,  1.42494396,  1.7824382 , ...,  1.02477511,
#         -0.8681323 ,  0.74231612],
#        [-0.97671633, -1.14569899, -1.46286291, ...,  1.02477511,
#         -0.8681323 ,  0.74231612]])

# %%
X_normalized.shape
# Out:
# (14999, 11)

# %% [markdown]
# ## Normalized Dataset
# The Dataset has been normalized and the distribution plot for a single sample is plotted below.

# %%
sns.distplot(X_normalized[11,:])

# %% [markdown]
# # Training and Cross-Validation

# %%
# train-test split
# ideal test size is 30%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %%
# shape of the training features
x_train.shape
# Out:
# (10499, 11)

# %%
# shape of the training labels
y_train.shape
# Out:
# (10499,)

# %%
# shape of the testing features
x_test.shape
# Out:
# (4500, 11)

# %%
# shape of the testing labels
y_test.shape
# Out:
# (4500,)

# %% [markdown]
# ## Binary Classification
# Binary or binomial classification is the task of classifying the elements of a given set into two groups (predicting which group each one belongs to) on the basis of a classification rule.

# %%
# importing models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# initializing all the models
models = []
models.append(['LR',LogisticRegression()])
models.append(['KNN',KNeighborsClassifier()])
models.append(['SVM',SVC()])
models.append(['DT',DecisionTreeClassifier()])
models.append(['RF',RandomForestClassifier()])
models.append(['AB',AdaBoostClassifier()])
models.append(['GNB',GaussianNB()])
models.append(['QDA',QuadraticDiscriminantAnalysis()])
models.append(['LDA',LinearDiscriminantAnalysis()])

# %%
len(models)
# Out:
# 9

# %% [markdown]
# ## Cross-validation
# Cross-validation is a technique to evaluate predictive models by partitioning the original sample into a training set to train the model, and a test set to evaluate it. In k-fold cross-validation, the original sample is randomly partitioned into k equal size subsamples.

# %%
from sklearn.cross_validation import KFold
from sklearn.model_selection import cross_val_score
kfold = KFold(1000, n_folds=10)

# %%
results = []
names = []
for name, model in models:
    print('training...' + name)
    scores = cross_val_score(model, x_train, y_train, cv=kfold, scoring='accuracy')
    names.append(name)
    results.append([ np.mean(scores), np.std(scores)])
    print(name + ' accuracy(mean):' + str(np.mean(scores)))
    print(name + ' accuracy(std):' + str(np.std(scores)))
    print('.......................................')
# Out:
# training...LR
# LR accuracy(mean):0.781
# LR accuracy(std):0.02947880594596736
# .......................................
# training...KNN
# KNN accuracy(mean):0.8789999999999999
# KNN accuracy(std):0.040607881008493926
# .......................................
# training...SVM
# SVM accuracy(mean):0.9040000000000001
# SVM accuracy(std):0.04294182110716779
# .......................................
# training...DT
# DT accuracy(mean):0.95
# DT accuracy(std):0.022360679774997883
# .......................................
# training...RF
# RF accuracy(mean):0.975
# RF accuracy(std):0.016278820596099686
# .......................................
# training...AB
# AB accuracy(mean):0.9480000000000001
# AB accuracy(std):0.015362291495737196
# .......................................
# training...GNB
# GNB accuracy(mean):0.688
# GNB accuracy(std):0.09754998718605759
# .......................................
# training...QDA
# QDA accuracy(mean):0.7619999999999999
# ...

# %% [markdown]
# ## RESULTS

# %%
results
# Out:
# [[0.781, 0.02947880594596736],
#  [0.8789999999999999, 0.040607881008493926],
#  [0.9040000000000001, 0.04294182110716779],
#  [0.95, 0.022360679774997883],
#  [0.975, 0.016278820596099686],
#  [0.9480000000000001, 0.015362291495737196],
#  [0.688, 0.09754998718605759],
#  [0.7619999999999999, 0.10943491216243564],
#  [0.7809999999999999, 0.028442925306655785]]

# %%
fig = plt.figure(figsize=(15,6))
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# ## Random Forest Classifier
# **Random Forest Classifier** clearly outperforms the other models and hence we shall choose it evaluate the test data.

# %%
random_forest = RandomForestClassifier()

# %%
training_score = random_forest.fit(x_train, y_train).score(x_train, y_train)

# %% [markdown]
# ## Training Score
# We get a training score of 99.8%

# %%
training_score
# Out:
# 0.9979998095056672

# %% [markdown]
# ## Evaluating the performance of the model

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
predict = random_forest.predict(x_test)

# %% [markdown]
# ## Confusion Matrix
# A confusion matrix is a table that is often used to describe the performance of a classification model (or "classifier") on a set of test data for which the true values are known.

# %%
print(confusion_matrix(y_test, predict))
# Out:
# [[3422    9]
#  [  38 1031]]

# %% [markdown]
# ### Accuracy
# Accuracy in classification problems is the number of correct predictions made by the model over all kinds predictions made.
# ### $Accuracy = \frac{TP + TN}{TP + FP + FN + TN}$
#
# ### Precision
# Precision is a measure that tells us what proportion of patients that we predicted to have left the company, actually left the company.
# ### $Precision = \frac{TP}{TP + FP}$

# %% [markdown]
# ### Classification Report
# The classification report displays the precision, recall, F1 score and the support for the model.

# %%
print(classification_report(y_test, predict))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      3431
#           1       0.99      0.96      0.98      1069
#
# avg / total       0.99      0.99      0.99      4500

# %% [markdown]
# # CONCLUSION
#  Finally, the **Random Forest algorithm** is found to be suitable for this problem which gives us an accuracy of 99%. Hence, we are able to predict the attrition of the organisation from the given features of the dataset.
